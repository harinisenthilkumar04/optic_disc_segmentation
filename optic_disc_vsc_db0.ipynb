# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from skimage.measure import find_contours
from skimage.morphology import skeletonize
from skimage.filters import gaussian
from skimage.draw import polygon
import cv2

image_folder = 'E:/PW2/DB0/images'
expert1_folder = 'E:/PW2/DB0/experts_anotation'
expert2_folder = 'E:/PW2/DB0/experts_anotation'
resized_folder = 'E:/PW2/DB0/resized_images2'
populated_folder = 'E:/PW2/DB0/populated_images2'
mask_folder = 'E:/PW2/DB0/u_net_masks2'

os.makedirs(resized_folder, exist_ok=True)
os.makedirs(populated_folder, exist_ok=True)
os.makedirs(mask_folder, exist_ok=True)

def load_coordinates(file_path):
    try:
        coords = np.genfromtxt(file_path, delimiter=',')
        if coords.ndim == 1:
            coords = coords.reshape(-1, 2)
        if coords.shape[1] != 2:
            raise ValueError(f"Invalid format in file: {file_path}")
        return coords
    except Exception as e:
        print(f"Error loading coordinates from {file_path}: {e}")
        return None

def coords_to_mask(coords, shape):
    mask = np.zeros(shape, dtype=np.uint8)
    rr, cc = polygon(coords[:, 1], coords[:, 0], shape)
    mask[rr, cc] = 1
    return mask

image_files = sorted([f for f in os.listdir(image_folder) if f.endswith(('.jpg', '.png'))])

for image_file in image_files:
    image_number = os.path.splitext(image_file)[0][-3:]
    expert1_file = os.path.join(expert1_folder, f'annotExpert1_{image_number}.txt')
    expert2_file = os.path.join(expert2_folder, f'annotExpert2_{image_number}.txt')

    image_path = os.path.join(image_folder, image_file)
    image = Image.open(image_path).convert('RGB')

    resized_image = image.resize((512, 512))
    resized_output_path = os.path.join(resized_folder, f'resized_{image_number}.png')
    resized_image.save(resized_output_path)

    expert1_coords = load_coordinates(expert1_file)
    expert2_coords = load_coordinates(expert2_file)

    if expert1_coords is None or expert2_coords is None:
        print(f"Skipping image {image_number} due to invalid annotation files.")
        continue

    original_shape = image.size[::-1]
    expert1_mask = coords_to_mask(expert1_coords, original_shape)
    expert2_mask = coords_to_mask(expert2_coords, original_shape)
    intersection_mask = expert1_mask & expert2_mask

    skeleton = skeletonize(intersection_mask > 0)

    skeleton_output_path = os.path.join(mask_folder, f'skeleton_{image_number}.png')
    Image.fromarray((skeleton * 255).astype(np.uint8)).save(skeleton_output_path)

    print(f'Saved Skeletonized Vessel Image: {skeleton_output_path}')

    vessel_convergence = cv2.distanceTransform((intersection_mask * 255).astype(np.uint8), cv2.DIST_L2, 3)
    vessel_convergence = gaussian(vessel_convergence, sigma=3)
    vessel_convergence_output_path = os.path.join(mask_folder, f'convergence_{image_number}.png')
    Image.fromarray((vessel_convergence * 255 / vessel_convergence.max()).astype(np.uint8)).save(vessel_convergence_output_path)

    print(f'Saved Vessel Convergence Image: {vessel_convergence_output_path}')

    input_size = (256, 256)
    image_np = np.array(resized_image)
    green_channel = image_np[:, :, 1]

    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_image = clahe.apply(green_channel)

    resized_enhanced = cv2.resize(enhanced_image, input_size) / 255.0
    resized_enhanced = np.expand_dims(resized_enhanced, axis=[0, -1])

    resized_mask = cv2.resize(intersection_mask, input_size, interpolation=cv2.INTER_NEAREST)
    resized_mask = np.expand_dims(resized_mask, axis=[0, -1])

    np.save(os.path.join(resized_folder, f'train_image_{image_number}.npy'), resized_enhanced)
    np.save(os.path.join(mask_folder, f'train_mask_{image_number}.npy'), resized_mask)

    print(f'Saved training data: {image_number}')

print("Preprocessing completed successfully!")
# Out:
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_001.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_001.png
# Saved training data: 001
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_002.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_002.png
# Saved training data: 002
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_003.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_003.png
# Saved training data: 003
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_004.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_004.png
# Saved training data: 004
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_005.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_005.png
# Saved training data: 005
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_006.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_006.png
# Saved training data: 006
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_007.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_007.png
# Saved training data: 007
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_008.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_008.png
# Saved training data: 008
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_009.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_009.png
# Saved training data: 009
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_010.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_010.png
# Saved training data: 010
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_011.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_011.png
# Saved training data: 011
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_012.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_012.png
# Saved training data: 012
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_013.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_013.png
# Saved training data: 013
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_014.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_014.png
# Saved training data: 014
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_015.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_015.png
# Saved training data: 015
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_016.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_016.png
# Saved training data: 016
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_017.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_017.png
# Saved training data: 017
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_018.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_018.png
# Saved training data: 018
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_019.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_019.png
# Saved training data: 019
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_020.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_020.png
# Saved training data: 020
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_021.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_021.png
# Saved training data: 021
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_022.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_022.png
# Saved training data: 022
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_023.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_023.png
# Saved training data: 023
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_024.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_024.png
# Saved training data: 024
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_025.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_025.png
# Saved training data: 025
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_026.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_026.png
# Saved training data: 026
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_027.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_027.png
# Saved training data: 027
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_028.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_028.png
# Saved training data: 028
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_029.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_029.png
# Saved training data: 029
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_030.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_030.png
# Saved training data: 030
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_031.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_031.png
# Saved training data: 031
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_032.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_032.png
# Saved training data: 032
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_033.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_033.png
# Saved training data: 033
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_034.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_034.png
# Saved training data: 034
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_035.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_035.png
# Saved training data: 035
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_036.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_036.png
# Saved training data: 036
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_037.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_037.png
# Saved training data: 037
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_038.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_038.png
# Saved training data: 038
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_039.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_039.png
# Saved training data: 039
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_040.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_040.png
# Saved training data: 040
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_041.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_041.png
# Saved training data: 041
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_042.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_042.png
# Saved training data: 042
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_043.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_043.png
# Saved training data: 043
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_044.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_044.png
# Saved training data: 044
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_045.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_045.png
# Saved training data: 045
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_046.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_046.png
# Saved training data: 046
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_047.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_047.png
# Saved training data: 047
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_048.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_048.png
# Saved training data: 048
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_049.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_049.png
# Saved training data: 049
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_050.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_050.png
# Saved training data: 050
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_051.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_051.png
# Saved training data: 051
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_052.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_052.png
# Saved training data: 052
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_053.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_053.png
# Saved training data: 053
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_054.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_054.png
# Saved training data: 054
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_055.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_055.png
# Saved training data: 055
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_056.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_056.png
# Saved training data: 056
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_057.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_057.png
# Saved training data: 057
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_058.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_058.png
# Saved training data: 058
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_059.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_059.png
# Saved training data: 059
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_060.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_060.png
# Saved training data: 060
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_061.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_061.png
# Saved training data: 061
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_062.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_062.png
# Saved training data: 062
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_063.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_063.png
# Saved training data: 063
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_064.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_064.png
# Saved training data: 064
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_065.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_065.png
# Saved training data: 065
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_066.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_066.png
# Saved training data: 066
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_067.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_067.png
# Saved training data: 067
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_068.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_068.png
# Saved training data: 068
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_069.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_069.png
# Saved training data: 069
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_070.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_070.png
# Saved training data: 070
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_071.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_071.png
# Saved training data: 071
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_072.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_072.png
# Saved training data: 072
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_073.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_073.png
# Saved training data: 073
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_074.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_074.png
# Saved training data: 074
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_075.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_075.png
# Saved training data: 075
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_076.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_076.png
# Saved training data: 076
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_077.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_077.png
# Saved training data: 077
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_078.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_078.png
# Saved training data: 078
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_079.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_079.png
# Saved training data: 079
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_080.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_080.png
# Saved training data: 080
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_081.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_081.png
# Saved training data: 081
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_082.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_082.png
# Saved training data: 082
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_083.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_083.png
# Saved training data: 083
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_084.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_084.png
# Saved training data: 084
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_085.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_085.png
# Saved training data: 085
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_086.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_086.png
# Saved training data: 086
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_087.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_087.png
# Saved training data: 087
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_088.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_088.png
# Saved training data: 088
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_089.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_089.png
# Saved training data: 089
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_090.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_090.png
# Saved training data: 090
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_091.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_091.png
# Saved training data: 091
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_092.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_092.png
# Saved training data: 092
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_093.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_093.png
# Saved training data: 093
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_094.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_094.png
# Saved training data: 094
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_095.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_095.png
# Saved training data: 095
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_096.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_096.png
# Saved training data: 096
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_097.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_097.png
# Saved training data: 097
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_098.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_098.png
# Saved training data: 098
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_099.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_099.png
# Saved training data: 099
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_100.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_100.png
# Saved training data: 100
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_101.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_101.png
# Saved training data: 101
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_102.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_102.png
# Saved training data: 102
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_103.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_103.png
# Saved training data: 103
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_104.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_104.png
# Saved training data: 104
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_105.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_105.png
# Saved training data: 105
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_106.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_106.png
# Saved training data: 106
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_107.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_107.png
# Saved training data: 107
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_108.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_108.png
# Saved training data: 108
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_109.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_109.png
# Saved training data: 109
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_110.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_110.png
# Saved training data: 110
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_111.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_111.png
# Saved training data: 111
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_112.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_112.png
# Saved training data: 112
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_113.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_113.png
# Saved training data: 113
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_114.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_114.png
# Saved training data: 114
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_115.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_115.png
# Saved training data: 115
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_116.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_116.png
# Saved training data: 116
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_117.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_117.png
# Saved training data: 117
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_118.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_118.png
# Saved training data: 118
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_119.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_119.png
# Saved training data: 119
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_120.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_120.png
# Saved training data: 120
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_121.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_121.png
# Saved training data: 121
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_122.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_122.png
# Saved training data: 122
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_123.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_123.png
# Saved training data: 123
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_124.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_124.png
# Saved training data: 124
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_125.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_125.png
# Saved training data: 125
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_126.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_126.png
# Saved training data: 126
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_127.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_127.png
# Saved training data: 127
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_128.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_128.png
# Saved training data: 128
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_129.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_129.png
# Saved training data: 129
# Saved Skeletonized Vessel Image: E:/PW2/DB0/u_net_masks2\skeleton_130.png
# Saved Vessel Convergence Image: E:/PW2/DB0/u_net_masks2\convergence_130.png
# Saved training data: 130
# Preprocessing completed successfully!

# %%
from PIL import Image
import numpy as np
import os
import cv2

superpixel_folder = 'E:/PW2/DB0/superpixel_maps'
mask_folder = 'E:/PW2/DB0/u_net_masks2'
resized_folder = 'E:/PW2/DB0/resized_images2'
final_u_net_folder = 'E:/PW2/DB0/u_net_input'

os.makedirs(final_u_net_folder, exist_ok=True)

image_files = sorted([f for f in os.listdir(resized_folder) if f.endswith('.png')])

for image_file in image_files:
    image_number = os.path.splitext(image_file)[0].split('_')[-1]
    image_path = os.path.join(resized_folder, image_file)
    image = np.array(Image.open(image_path).convert('RGB'))
    green_channel = image[:, :, 1] / 255.0
    superpixel_path = os.path.join(superpixel_folder, f'superpixel_resized_{image_number}.png')
    superpixel_map = np.array(Image.open(superpixel_path).convert('L')) / 255.0
    skeleton_path = os.path.join(mask_folder, f'skeleton_{image_number}.png')
    skeleton_map = np.array(Image.open(skeleton_path).convert('L')) / 255.0
    convergence_path = os.path.join(mask_folder, f'convergence_{image_number}.png')
    convergence_map = np.array(Image.open(convergence_path).convert('L')) / 255.0
    input_size = (256, 256)
    green_channel = cv2.resize(green_channel, input_size)
    superpixel_map = cv2.resize(superpixel_map, input_size)
    skeleton_map = cv2.resize(skeleton_map, input_size)
    convergence_map = cv2.resize(convergence_map, input_size)

    u_net_input = np.stack([green_channel, superpixel_map, skeleton_map, convergence_map], axis=-1)

    np.save(os.path.join(final_u_net_folder, f'u_net_input_{image_number}.npy'), u_net_input)

    print(f'Saved multi-channel U-Net input: {image_number}')

print("U-Net input generation completed successfully!")
# Out:
# Saved multi-channel U-Net input: 001
# Saved multi-channel U-Net input: 002
# Saved multi-channel U-Net input: 003
# Saved multi-channel U-Net input: 004
# Saved multi-channel U-Net input: 005
# Saved multi-channel U-Net input: 006
# Saved multi-channel U-Net input: 007
# Saved multi-channel U-Net input: 008
# Saved multi-channel U-Net input: 009
# Saved multi-channel U-Net input: 010
# Saved multi-channel U-Net input: 011
# Saved multi-channel U-Net input: 012
# Saved multi-channel U-Net input: 013
# Saved multi-channel U-Net input: 014
# Saved multi-channel U-Net input: 015
# Saved multi-channel U-Net input: 016
# Saved multi-channel U-Net input: 017
# Saved multi-channel U-Net input: 018
# Saved multi-channel U-Net input: 019
# Saved multi-channel U-Net input: 020
# Saved multi-channel U-Net input: 021
# Saved multi-channel U-Net input: 022
# Saved multi-channel U-Net input: 023
# Saved multi-channel U-Net input: 024
# Saved multi-channel U-Net input: 025
# Saved multi-channel U-Net input: 026
# Saved multi-channel U-Net input: 027
# Saved multi-channel U-Net input: 028
# Saved multi-channel U-Net input: 029
# Saved multi-channel U-Net input: 030
# Saved multi-channel U-Net input: 031
# Saved multi-channel U-Net input: 032
# Saved multi-channel U-Net input: 033
# Saved multi-channel U-Net input: 034
# Saved multi-channel U-Net input: 035
# Saved multi-channel U-Net input: 036
# Saved multi-channel U-Net input: 037
# Saved multi-channel U-Net input: 038
# Saved multi-channel U-Net input: 039
# Saved multi-channel U-Net input: 040
# Saved multi-channel U-Net input: 041
# Saved multi-channel U-Net input: 042
# Saved multi-channel U-Net input: 043
# Saved multi-channel U-Net input: 044
# Saved multi-channel U-Net input: 045
# Saved multi-channel U-Net input: 046
# Saved multi-channel U-Net input: 047
# Saved multi-channel U-Net input: 048
# Saved multi-channel U-Net input: 049
# Saved multi-channel U-Net input: 050
# Saved multi-channel U-Net input: 051
# Saved multi-channel U-Net input: 052
# Saved multi-channel U-Net input: 053
# Saved multi-channel U-Net input: 054
# Saved multi-channel U-Net input: 055
# Saved multi-channel U-Net input: 056
# Saved multi-channel U-Net input: 057
# Saved multi-channel U-Net input: 058
# Saved multi-channel U-Net input: 059
# Saved multi-channel U-Net input: 060
# Saved multi-channel U-Net input: 061
# Saved multi-channel U-Net input: 062
# Saved multi-channel U-Net input: 063
# Saved multi-channel U-Net input: 064
# Saved multi-channel U-Net input: 065
# Saved multi-channel U-Net input: 066
# Saved multi-channel U-Net input: 067
# Saved multi-channel U-Net input: 068
# Saved multi-channel U-Net input: 069
# Saved multi-channel U-Net input: 070
# Saved multi-channel U-Net input: 071
# Saved multi-channel U-Net input: 072
# Saved multi-channel U-Net input: 073
# Saved multi-channel U-Net input: 074
# Saved multi-channel U-Net input: 075
# Saved multi-channel U-Net input: 076
# Saved multi-channel U-Net input: 077
# Saved multi-channel U-Net input: 078
# Saved multi-channel U-Net input: 079
# Saved multi-channel U-Net input: 080
# Saved multi-channel U-Net input: 081
# Saved multi-channel U-Net input: 082
# Saved multi-channel U-Net input: 083
# Saved multi-channel U-Net input: 084
# Saved multi-channel U-Net input: 085
# Saved multi-channel U-Net input: 086
# Saved multi-channel U-Net input: 087
# Saved multi-channel U-Net input: 088
# Saved multi-channel U-Net input: 089
# Saved multi-channel U-Net input: 090
# Saved multi-channel U-Net input: 091
# Saved multi-channel U-Net input: 092
# Saved multi-channel U-Net input: 093
# Saved multi-channel U-Net input: 094
# Saved multi-channel U-Net input: 095
# Saved multi-channel U-Net input: 096
# Saved multi-channel U-Net input: 097
# Saved multi-channel U-Net input: 098
# Saved multi-channel U-Net input: 099
# Saved multi-channel U-Net input: 100
# Saved multi-channel U-Net input: 101
# Saved multi-channel U-Net input: 102
# Saved multi-channel U-Net input: 103
# Saved multi-channel U-Net input: 104
# Saved multi-channel U-Net input: 105
# Saved multi-channel U-Net input: 106
# Saved multi-channel U-Net input: 107
# Saved multi-channel U-Net input: 108
# Saved multi-channel U-Net input: 109
# Saved multi-channel U-Net input: 110
# Saved multi-channel U-Net input: 111
# Saved multi-channel U-Net input: 112
# Saved multi-channel U-Net input: 113
# Saved multi-channel U-Net input: 114
# Saved multi-channel U-Net input: 115
# Saved multi-channel U-Net input: 116
# Saved multi-channel U-Net input: 117
# Saved multi-channel U-Net input: 118
# Saved multi-channel U-Net input: 119
# Saved multi-channel U-Net input: 120
# Saved multi-channel U-Net input: 121
# Saved multi-channel U-Net input: 122
# Saved multi-channel U-Net input: 123
# Saved multi-channel U-Net input: 124
# Saved multi-channel U-Net input: 125
# Saved multi-channel U-Net input: 126
# Saved multi-channel U-Net input: 127
# Saved multi-channel U-Net input: 128
# Saved multi-channel U-Net input: 129
# Saved multi-channel U-Net input: 130
# U-Net input generation completed successfully!

# %%
import os
from sklearn.model_selection import train_test_split

image_folder = 'E:/PW2/DB0/u_net_input'
mask_folder = 'E:/PW2/DB0/u_net_masks'
x_files = sorted([f for f in os.listdir(image_folder) if f.endswith('.npy')])
y_files = sorted([f for f in os.listdir(mask_folder) if f.endswith('.png')])
if not x_files:
    raise ValueError("No input image files found in the specified folder!")
if not y_files:
    raise ValueError("No mask files found in the specified folder!")

valid_pairs = []
for x in x_files:
    image_number = os.path.splitext(x)[0].split('_')[-1]
    mask_name = f"mask_{image_number}.png"
    mask_path = os.path.join(mask_folder, mask_name)
    if os.path.exists(mask_path):
        valid_pairs.append((x, mask_name))
    else:
        print(f"⚠️ Missing mask file: {mask_path}")
if not valid_pairs:
    raise ValueError("No valid (image, mask) pairs found! Check file paths and naming consistency.")
x_files, y_files = zip(*valid_pairs)
X_train_files, X_val_files, Y_train_files, Y_val_files = train_test_split(
    x_files, y_files, test_size=0.2, random_state=42
)
print(f"✅ Training samples: {len(X_train_files)}")
print(f"✅ Validation samples: {len(X_val_files)}")

with open("train_files.txt", "w") as f:
    f.write("\n".join(X_train_files))

with open("val_files.txt", "w") as f:
    f.write("\n".join(X_val_files))

print("📌 Data split successfully!")
# Out:
# ✅ Training samples: 104
# ✅ Validation samples: 26
# 📌 Data split successfully!

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split

input_folder = 'E:/PW2/DB0/u_net_input'
mask_folder = 'E:/PW2/DB0/u_net_masks'

x_files = sorted([f for f in os.listdir(input_folder) if f.endswith('.npy')])
y_files = sorted([f for f in os.listdir(mask_folder) if f.endswith('.png')])

valid_pairs = [(x, y) for x, y in zip(x_files, y_files) if os.path.exists(os.path.join(mask_folder, y))]

if not valid_pairs:
    raise ValueError("⚠️ No valid image-mask pairs found! Check filenames.")

x_files, y_files = zip(*valid_pairs)

print(f"✅ Found {len(x_files)} valid pairs.")
# Out:
# ✅ Found 130 valid pairs.

# %%
X_train_files, X_val_files, Y_train_files, Y_val_files = train_test_split(
    x_files, y_files, test_size=0.2, random_state=42
)

print(f"✅ Training samples: {len(X_train_files)}, Validation samples: {len(X_val_files)}")
# Out:
# ✅ Training samples: 104, Validation samples: 26

# %%
import cv2
from tensorflow.keras.utils import to_categorical
def load_data(x_file_list, y_file_list, input_folder, mask_folder, img_size=(256, 256)):
    X_data, Y_data = [], []

    for x_file, y_file in zip(x_file_list, y_file_list):
        x_path = os.path.join(input_folder, x_file)
        x_image = np.load(x_path)
        y_path = os.path.join(mask_folder, y_file)
        y_mask = cv2.imread(y_path, cv2.IMREAD_GRAYSCALE)
        y_mask = cv2.resize(y_mask, img_size)
        y_mask = y_mask / 255.0
        y_mask = np.expand_dims(y_mask, axis=-1)
        X_data.append(x_image)
        Y_data.append(y_mask)

    return np.array(X_data), np.array(Y_data)

X_train, Y_train = load_data(X_train_files, Y_train_files, input_folder, mask_folder)
X_val, Y_val = load_data(X_val_files, Y_val_files, input_folder, mask_folder)

print(f"✅ X_train shape: {X_train.shape}, Y_train shape: {Y_train.shape}")
print(f"✅ X_val shape: {X_val.shape}, Y_val shape: {Y_val.shape}")
# Out:
# ✅ X_train shape: (104, 256, 256, 4), Y_train shape: (104, 256, 256, 1)
# ✅ X_val shape: (26, 256, 256, 4), Y_val shape: (26, 256, 256, 1)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Dropout
from tensorflow.keras.models import Model

def unet_model(input_size=(256, 256, 4)):
    inputs = Input(input_size)

    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
    c5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(c5)

    u6 = UpSampling2D((2, 2))(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    c6 = Conv2D(512, (3, 3), activation='relu', padding='same')(c6)

    u7 = UpSampling2D((2, 2))(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    c7 = Conv2D(256, (3, 3), activation='relu', padding='same')(c7)

    u8 = UpSampling2D((2, 2))(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    c8 = Conv2D(128, (3, 3), activation='relu', padding='same')(c8)

    u9 = UpSampling2D((2, 2))(c8)
    u9 = concatenate([u9, c1])
    c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    c9 = Conv2D(64, (3, 3), activation='relu', padding='same')(c9)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return model

unet = unet_model()
unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 4)]        0         []
#
#  conv2d (Conv2D)             (None, 256, 256, 64)         2368      ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 64)         36928     ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 64)         0         ['conv2d_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 128)        73856     ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 128)        147584    ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 128)          0         ['conv2d_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 256)          295168    ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 256)          590080    ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 256)          0         ['conv2d_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 512)          1180160   ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 512)          2359808   ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 512)          0         ['conv2d_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 1024)         4719616   ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 16, 16, 1024)         9438208   ['conv2d_8[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 1024)         0         ['conv2d_9[0][0]']
#  D)
#
#  concatenate (Concatenate)   (None, 32, 32, 1536)         0         ['up_sampling2d[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 512)          7078400   ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 512)          2359808   ['conv2d_10[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 512)          0         ['conv2d_11[0][0]']
#  g2D)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 768)          0         ['up_sampling2d_1[0][0]',
#  )                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 64, 64, 256)          1769728   ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 64, 64, 256)          590080    ['conv2d_12[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 256)        0         ['conv2d_13[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 384)        0         ['up_sampling2d_2[0][0]',
#  )                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 128, 128, 128)        442496    ['concatenate_2[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 128, 128, 128)        147584    ['conv2d_14[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 128)        0         ['conv2d_15[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 256, 256, 192)        0         ['up_sampling2d_3[0][0]',
#  )                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 256, 256, 64)         110656    ['concatenate_3[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 256, 256, 64)         36928     ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 1)          65        ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 31379521 (119.70 MB)
# Trainable params: 31379521 (119.70 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
history = unet.fit(
    X_train, Y_train,
    validation_data=(X_val, Y_val),
    epochs=20,
    batch_size=8,
    verbose=1
)
# Out:
# Epoch 1/20
# 13/13 [==============================] - 457s 35s/step - loss: 1.3314 - accuracy: 0.9844 - val_loss: 0.1099 - val_accuracy: 0.9848
# Epoch 2/20
# 13/13 [==============================] - 433s 33s/step - loss: 0.1083 - accuracy: 0.9846 - val_loss: 0.0736 - val_accuracy: 0.9848
# Epoch 3/20
# 13/13 [==============================] - 521s 41s/step - loss: 0.0624 - accuracy: 0.9846 - val_loss: 0.0413 - val_accuracy: 0.9848
# Epoch 4/20
# 13/13 [==============================] - 378s 29s/step - loss: 0.0301 - accuracy: 0.9857 - val_loss: 0.0234 - val_accuracy: 0.9884
# Epoch 5/20
# 13/13 [==============================] - 280s 21s/step - loss: 0.0215 - accuracy: 0.9922 - val_loss: 0.0182 - val_accuracy: 0.9930
# Epoch 6/20
# 13/13 [==============================] - 234s 18s/step - loss: 0.0146 - accuracy: 0.9940 - val_loss: 0.0152 - val_accuracy: 0.9935
# Epoch 7/20
# 13/13 [==============================] - 223s 17s/step - loss: 0.0132 - accuracy: 0.9944 - val_loss: 0.0145 - val_accuracy: 0.9938
# Epoch 8/20
# 13/13 [==============================] - 223s 17s/step - loss: 0.0116 - accuracy: 0.9949 - val_loss: 0.0135 - val_accuracy: 0.9941
# Epoch 9/20
# 13/13 [==============================] - 224s 17s/step - loss: 0.0278 - accuracy: 0.9920 - val_loss: 0.0364 - val_accuracy: 0.9919
# Epoch 10/20
# 13/13 [==============================] - 224s 17s/step - loss: 0.0194 - accuracy: 0.9936 - val_loss: 0.0266 - val_accuracy: 0.9905
# Epoch 11/20
# 13/13 [==============================] - 224s 17s/step - loss: 0.0132 - accuracy: 0.9942 - val_loss: 0.0130 - val_accuracy: 0.9946
# Epoch 12/20
# 13/13 [==============================] - 223s 17s/step - loss: 0.0099 - accuracy: 0.9957 - val_loss: 0.0098 - val_accuracy: 0.9956
# Epoch 13/20
# 13/13 [==============================] - 224s 17s/step - loss: 0.0088 - accuracy: 0.9959 - val_loss: 0.0090 - val_accuracy: 0.9961
# Epoch 14/20
# 13/13 [==============================] - 223s 17s/step - loss: 0.0076 - accuracy: 0.9964 - val_loss: 0.0090 - val_accuracy: 0.9960
# Epoch 15/20
# 13/13 [==============================] - 223s 17s/step - loss: 0.0082 - accuracy: 0.9963 - val_loss: 0.0110 - val_accuracy: 0.9956
# Epoch 16/20
# 13/13 [==============================] - 223s 17s/step - loss: 0.0068 - accuracy: 0.9967 - val_loss: 0.0073 - val_accuracy: 0.9967
# Epoch 17/20
# 13/13 [==============================] - 223s 17s/step - loss: 0.0058 - accuracy: 0.9971 - val_loss: 0.0085 - val_accuracy: 0.9966
# Epoch 18/20
# 13/13 [==============================] - 229s 18s/step - loss: 0.0056 - accuracy: 0.9971 - val_loss: 0.0067 - val_accuracy: 0.9970
# Epoch 19/20
# 13/13 [==============================] - 233s 18s/step - loss: 0.0042 - accuracy: 0.9977 - val_loss: 0.0060 - val_accuracy: 0.9974
# Epoch 20/20
# 13/13 [==============================] - 229s 18s/step - loss: 0.0037 - accuracy: 0.9979 - val_loss: 0.0054 - val_accuracy: 0.9976

# %%
unet.save("E:/PW2/DB0/u_net_segmentation_model.h5")
print("✅ Model saved successfully!")
# Out:
# C:\Users\Venkat\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# ✅ Model saved successfully!

# %%
import os
import numpy as np
import cv2
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, jaccard_score

input_folder = 'E:/PW2/DB0/u_net_input'
mask_folder = 'E:/PW2/DB0/u_net_masks'
def load_test_data(x_files, y_files, input_folder, mask_folder, img_size=(256, 256)):
    X_test, Y_test = [], []

    for x_file, y_file in zip(x_files, y_files):
        x_path = os.path.join(input_folder, x_file)
        x_image = np.load(x_path)
        y_path = os.path.join(mask_folder, y_file)
        y_mask = cv2.imread(y_path, cv2.IMREAD_GRAYSCALE)
        y_mask = cv2.resize(y_mask, img_size) / 255.0
        y_mask = np.expand_dims(y_mask, axis=-1)
        X_test.append(x_image)
        Y_test.append(y_mask)

    return np.array(X_test), np.array(Y_test)

X_test, Y_test = load_test_data(x_files, y_files, input_folder, mask_folder)

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    intersection = np.sum(y_true * y_pred)
    union = np.sum(y_true) + np.sum(y_pred)
    return (2. * intersection + smooth) / (union + smooth)

def evaluate_model(model, X_test, Y_test, threshold=0.5):

    Y_pred = model.predict(X_test)
    Y_pred = (Y_pred > threshold).astype(np.uint8)
    Y_test_flat = (Y_test > 0.5).astype(np.uint8).flatten()
    Y_pred_flat = Y_pred.flatten()


    accuracy = accuracy_score(Y_test_flat, Y_pred_flat)
    precision = precision_score(Y_test_flat, Y_pred_flat)
    recall = recall_score(Y_test_flat, Y_pred_flat)
    f1 = f1_score(Y_test_flat, Y_pred_flat)
    dice = dice_coefficient(Y_test_flat, Y_pred_flat)
    iou = jaccard_score(Y_test_flat, Y_pred_flat)

    print(f"✅ Accuracy: {accuracy:.4f}")
    print(f"✅ Precision: {precision:.4f}")
    print(f"✅ Recall: {recall:.4f}")
    print(f"✅ F1-score: {f1:.4f}")
    print(f"✅ Dice Score: {dice:.4f}")
    print(f"✅ IoU (Jaccard Index): {iou:.4f}")

    return accuracy, precision, recall, f1, dice, iou

evaluate_model(unet, X_test, Y_test)
# Out:
# 5/5 [==============================] - 68s 13s/step
# ✅ Accuracy: 0.9986
# ✅ Precision: 0.9596
# ✅ Recall: 0.9504
# ✅ F1-score: 0.9550
# ✅ Dice Score: 0.9550
# ✅ IoU (Jaccard Index): 0.9138
# (0.9986480712890625,
#  0.9595604706548139,
#  0.9503872951617298,
#  0.9549518542564592,
#  0.9549518542566354,
#  0.9137874251497006)
